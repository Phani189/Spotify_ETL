# %% [markdown]
# ### Requirments

# %%
# %pip install snowflake-ingest
# %pip install snowflake-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# Set environment variables
os.environ['SNOWFLAKE_USER'] = 'python_user_login'
os.environ['SNOWFLAKE_PASSWORD'] = 'Phanipyload@66'
os.environ['SNOWFLAKE_ACCOUNT'] = 'HENVDEC-QO50665'

# %%
import os
import snowflake.connector

# Load credentials from environment variables
user = os.getenv('SNOWFLAKE_USER')
password = os.getenv('SNOWFLAKE_PASSWORD')
account = os.getenv('SNOWFLAKE_ACCOUNT')

# connection details
if not user or not password or not account:
    raise ValueError("Please set SNOWFLAKE_USER, SNOWFLAKE_PASSWORD, and SNOWFLAKE_ACCOUNT environment variables.")

# Connect to Snowflake using the credentials from environment variables

con = snowflake.connector.connect(
    user=user,
    password=password,
    account=account
)

# Create a cursor object
cur = con.cursor()

# Example: Set role and warehouse

# %%
import os

# Set environment variables
os.environ['RSA_KEY_PASSPHRASE'] = 'Phanipykey@66'

# %%
from cryptography.hazmat.primitives import serialization
from cryptography.hazmat.primitives.asymmetric import rsa
from cryptography.hazmat.backends import default_backend

# Define a passphrase for encrypting the private key
passphrase =  os.getenv("RSA_KEY_PASSPHRASE").encode()


# Generate RSA private key
private_key = rsa.generate_private_key(
    public_exponent=65537,
    key_size=2048,
    backend=default_backend()
)

# Save encrypted private key to .p8 file
with open("rsa_key_encrypted.p8", "wb") as private_file:
    private_file.write(
        private_key.private_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PrivateFormat.PKCS8,
            encryption_algorithm=serialization.BestAvailableEncryption(passphrase)
        )
    )

# Extract and save public key to .pub file
public_key = private_key.public_key()
with open("rsa_key.pub", "wb") as public_file:
    public_file.write(
        public_key.public_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PublicFormat.SubjectPublicKeyInfo
        )
    )

print("✅ Encrypted private key saved to 'rsa_key_encrypted.p8'")
print("✅ Public key saved to 'rsa_key.pub'")
# Out:
# ✅ Encrypted private key saved to 'rsa_key_encrypted.p8'
# ✅ Public key saved to 'rsa_key.pub'
